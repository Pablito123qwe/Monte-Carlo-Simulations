# %%
import sin
import math
start = 0
end = math.pi
N = 1000

# %%
print("Wynik dla 1000 prostokątów: ", sin.rectangular_integration(start, end, N))
# Out:
# Wynik dla 1000 prostokątów:  1.9999983550656877

# %%
print("Wynik dla 1000 trapezów: ", sin.trapezoidal_integration(start, end, N))
# Out:
# Wynik dla 1000 trapezów:  1.9999983550656886

# %%
print("Zbieżność błędów dla prostokątów: ")
x,y = sin.rectangular_integration_accuracy(1000)
sin.plot_errors(x, y)
# Out:
# Zbieżność błędów dla prostokątów:

# %%
print("Zbieżność błędów dla trapezów: ")
x,y = sin.trapezoidal_integration_accuracy(1000)
sin.plot_errors(x, y)
# Out:
# Zbieżność błędów dla trapezów:
